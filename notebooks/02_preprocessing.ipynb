# %% [markdown]
# # Member 1 preprocessing
#
# Run the same portable preprocessing used by the command-line pipeline.

# %%
from src.data.preprocess import preprocess_csv

clean = preprocess_csv()
clean.head(), clean.shape, clean['was_imputed'].value_counts()
