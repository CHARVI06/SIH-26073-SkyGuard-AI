# %% [markdown]
# # Isolation Forest baseline
#
# Use `python -m src.run_member1` for the reproducible chronological train/holdout evaluation and artifact generation.

# %%
from src.run_member1 import main

# Run from the repository root in a terminal:
# python -m src.run_member1
